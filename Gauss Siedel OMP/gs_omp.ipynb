# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('D:\Masters\Spring2023\CprE 525 Numerical Analysis for HPC\data.csv', sep=';')

# %%
data.head()
# Out:
#    thread_count  MatrixSize  Total_time_serial  total_time_parallel
# 0             2          64           0.003402             0.002309
# 1             4         128           0.013517             0.004629
# 2             6         256           0.054041             0.011588
# 3            12         512           0.216651             0.023780
# 4            16        1024           0.956713             0.066077

# %%
    data.tail()
# Out:
#    thread_count  MatrixSize  Total_time_serial  total_time_parallel
# 1             4         128           0.013517             0.004629
# 2             6         256           0.054041             0.011588
# 3            12         512           0.216651             0.023780
# 4            16        1024           0.956713             0.066077
# 5            32        2048           3.805083             0.427421

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
print(data)
# Out:
#    thread_count  MatrixSize  Total_time_serial  total_time_parallel
# 0             2          64           0.003402             0.002309
# 1             4         128           0.013517             0.004629
# 2             6         256           0.054041             0.011588
# 3            12         512           0.216651             0.023780
# 4            16        1024           0.956713             0.066077
# 5            32        2048           3.805083             0.427421

# %%
import seaborn as sns
import matplotlib.pyplot as plt

thread_count = [2, 4, 6, 12, 16, 32]
matrix_size = [64, 128, 256, 512, 1024, 2048]
total_time_serial = [0.003402, 0.013517, 0.054041, 0.216651, 0.956713, 3.805083]
total_time_parallel = [0.002309, 0.004629, 0.011588, 0.023780, 0.066077, 0.427421]

sns.lineplot(data=data, x="thread_count", y="Total_time_serial")

# plot configuration
plt.title("Total_serial_time vs. Thread count")
plt.xlabel("thread_count")
plt.ylabel("total_time_serial")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

thread_count = [2, 4, 6, 12, 16, 32]
matrix_size = [64, 128, 256, 512, 1024, 2048]
total_time_serial = [0.003402, 0.013517, 0.054041, 0.216651, 0.956713, 3.805083]
total_time_parallel = [0.002309, 0.004629, 0.011588, 0.023780, 0.066077, 0.427421]

sns.lineplot(data=data, x="thread_count", y="total_time_parallel")

# plot configuration
plt.title("Total_parallel_time vs. Thread count")
plt.xlabel("thread_count")
plt.ylabel("total_time_parallel")
plt.show()
